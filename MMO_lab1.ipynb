# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

import chardet

from os import path
data = pd.read_csv(path.join('C:\\Users\\nika.pinskaya\\Documents\\BMSTU\\MMO\\data-master\\airline-safety', 'airline-safety.csv'), sep=',')
data.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
data = data.drop(columns=['fatal_accidents_00_14', 'fatalities_00_14'], axis=1)
data.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2

# %%
data = data.dropna()
data.dtypes
# Out:
# airline                   object
# avail_seat_km_per_week     int64
# incidents_85_99            int64
# fatal_accidents_85_99      int64
# fatalities_85_99           int64
# incidents_00_14            int64
# dtype: object

# %%
data.describe()
# Out:
#        avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# count            5.600000e+01        56.000000              56.000000
# mean             1.384621e+09         7.178571               2.178571
# std              1.465317e+09        11.035656               2.861069
# min              2.593733e+08         0.000000               0.000000
# 25%              4.740362e+08         2.000000               0.000000
# 50%              8.029089e+08         4.000000               1.000000
# 75%              1.847239e+09         8.000000               3.000000
# max              7.139291e+09        76.000000              14.000000
#
#        fatalities_85_99  incidents_00_14
# count         56.000000        56.000000
# mean         112.410714         4.125000
# std          146.691114         4.544977
# min            0.000000         0.000000
# 25%            0.000000         1.000000
# 50%           48.500000         3.000000
# 75%          184.250000         5.250000
# ...

# %%
max_seat_kilo = data['avail_seat_km_per_week'].max()
most_active_airline = data.loc[(data['avail_seat_km_per_week'] == max_seat_kilo)]
most_active_airline
# Out:
#                   airline  avail_seat_km_per_week  incidents_85_99  \
# 51  United / Continental*              7139291291               19
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14
# 51                      8               319               14

# %%
g = sns.regplot(x=data['avail_seat_km_per_week'], y=data['incidents_85_99'], x_estimator=np.mean, line_kws={"color":"r","alpha":0.7,"lw":1})
g.get_figure().set_size_inches(10, 10)
plt.show()

# %%
data['airline'].unique()
# Out:
# array(['Aer Lingus', 'Aeroflot*', 'Aerolineas Argentinas', 'Aeromexico*',
#        'Air Canada', 'Air France', 'Air India*', 'Air New Zealand*',
#        'Alaska Airlines*', 'Alitalia', 'All Nippon Airways', 'American*',
#        'Austrian Airlines', 'Avianca', 'British Airways*',
#        'Cathay Pacific*', 'China Airlines', 'Condor', 'COPA',
#        'Delta / Northwest*', 'Egyptair', 'El Al', 'Ethiopian Airlines',
#        'Finnair', 'Garuda Indonesia', 'Gulf Air', 'Hawaiian Airlines',
#        'Iberia', 'Japan Airlines', 'Kenya Airways', 'KLM*', 'Korean Air',
#        'LAN Airlines', 'Lufthansa*', 'Malaysia Airlines',
#        'Pakistan International', 'Philippine Airlines', 'Qantas*',
#        'Royal Air Maroc', 'SAS*', 'Saudi Arabian', 'Singapore Airlines',
#        'South African', 'Southwest Airlines', 'Sri Lankan / AirLanka',
#        'SWISS*', 'TACA', 'TAM', 'TAP - Air Portugal', 'Thai Airways',
#        'Turkish Airlines', 'United / Continental*',
# ...

# %%
g = sns.boxplot( y=data['incidents_85_99'], x=data['airline'] )
g.get_figure().set_size_inches(10, 10)
plt.xticks(fontsize='17')
plt.yticks(fontsize='17')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.,  80.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
from os import path
data_NA = pd.read_csv(path.join('C:\\Users\\nika.pinskaya\\Documents\\BMSTU\\MMO\\data-master\\airline-safety', 'airline-safety_not_all.csv'), sep=',')
data_NA.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
data_NA['airline'].unique()
# Out:
# array(['Aer Lingus', 'Aeroflot*', 'Aerolineas Argentinas', 'Aeromexico*',
#        'Air Canada', 'Air France', 'Air India*', 'Air New Zealand*',
#        'Alaska Airlines*', 'Alitalia', 'All Nippon Airways', 'American*',
#        'Austrian Airlines', 'Avianca', 'British Airways*',
#        'Cathay Pacific*', 'China Airlines', 'Condor', 'COPA'],
#       dtype=object)

# %%
g = sns.boxplot( y=data_NA['fatalities_85_99'], x=data_NA['airline'] )
g.get_figure().set_size_inches(10, 10)
plt.xticks(fontsize='17')
plt.yticks(fontsize='17')
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# define colors
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3, BLUE4 = '#174A7E', '#4A81BF', '#94B2D7', '#94AFC5'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'
ORANGE1 = '#F79747'
# configure plot font family to Arial
plt.rcParams['font.family'] = 'Arial'
# configure mathtext bold and italic font family to Arial
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'

# %%
max_seat_kiloNA = data_NA['avail_seat_km_per_week'].max()
incidents_85_99	 = data_NA.loc[(data_NA['avail_seat_km_per_week'] == max_seat_kiloNA)]
most_active_airlineNA
# Out:
#       airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# 11  American*              5228357340               21                      5
#
#     fatalities_85_99  incidents_00_14  fatal_accidents_00_14  fatalities_00_14
# 11               101               17                      3               416

# %%
# create new figure
plt.figure(figsize=(7.45, 4.9), # width, height in inches
dpi=110) # resolution of the figure
# remove chart border
for spine in plt.gca().spines.values():
    spine.set_visible(False)
# change the appearance of ticks, tick labels, and gridlines
plt.tick_params(bottom='off', left='off', labelleft='off', labelbottom='off')
plt.axis('off')
# titile the plot
plt.text(-0.15, 1.03,
'The most active airline:',
fontsize=26,
color='white',
# put a rectangular box around the text to set a background color
bbox={'facecolor': BLUE4, 'pad': 10, 'edgecolor': 'none'})
# add note to the plot
plt.text(-0.15, 0.05,
    '{}'.format(most_active_airlineNA['airline'].values[0]), # use mathtext \\bf for bold text
    fontsize=122,
    color=BLUE4)
# add note to the plot
plt.text(-0.15, 0.81,
    '{} · {} · {}'.format(most_active_airlineNA['incidents_85_99'].values[0], most_active_airlineNA['fatal_accidents_85_99'].values[0], most_active_airlineNA['fatalities_85_99'].values[0]),
    fontsize=19,
    color=BLUE2)
# add note to the plot
plt.text(-0.15, 0.41,
    '{}$'.format(round(most_active_airlineNA['avail_seat_km_per_week'].values[0])), # use mathtext \\bf for bold text
    fontsize=122,
    color=BLUE2)
# add note to the plot
plt.text(-0.15, -0.05,
    '{} · {} · {}'.format(most_active_airlineNA['incidents_00_14'].values[0], most_active_airlineNA['fatal_accidents_00_14'].values[0], most_active_airlineNA['fatalities_00_14'].values[0]),
    fontsize=19,
    color=GRAY7)
# Out:
# Text(-0.15, -0.05, '17 · 3 · 416')

# %%
data_variety = data.loc[(data['airline'].isin(['Aeroflot*', 'Alitalia', 'Turkish Airlines', 'El Al']))]
data_variety.shape
# Out:
# (4, 6)

# %%
data_variety.head()
# Out:
#              airline  avail_seat_km_per_week  incidents_85_99  \
# 1          Aeroflot*              1197672318               76
# 9           Alitalia               698012498                7
# 21             El Al               335448023                1
# 50  Turkish Airlines              1946098294                8
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14
# 1                      14               128                6
# 9                       2                50                4
# 21                      1                 4                1
# 50                      3                64                8

# %%
print(data_variety.loc[(data['airline']=='Aeroflot*')].shape)
print(data_variety.loc[(data['airline']=='Alitalia')].shape)
print(data_variety.loc[(data['airline']=='Turkish Airlines')].shape)
print(data_variety.loc[(data['airline']=='El Al')].shape)
# Out:
# (1, 6)
# (1, 6)
# (1, 6)
# (1, 6)

# %%
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=12,8
# set seaborn whitegrid theme
sns.set(style="whitegrid")
# Without transparency
sns.kdeplot(data=data_variety, x="avail_seat_km_per_week", hue="airline", cut=0, fill=True, common_norm=False, alpha=0.4)
plt.show()
# Out:
# C:\Users\nika.pinskaya\Anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
import networkx as nx
G = nx.from_pandas_edgelist(data_NA, 'incidents_85_99', 'fatal_accidents_85_99')
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", node_shape="s", alpha=0.5, linewidths=40)
plt.show()

# %%
import networkx as nx
G = nx.from_pandas_edgelist(data_NA, 'airline', 'fatal_accidents_85_99')
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", node_shape="s", alpha=0.5, linewidths=40)
plt.show()

# %%
# Create data 
my_variable=data_NA(np.random.normal(1000, 0, 2) , np.random.normal(1000, 9, 2))
 
# Layout to split the screen
layout(mat = matrix(data_NA(1,2),2,1, byrow=TRUE),  height = data_NA(1,8))
 
# Draw the boxplot and the histogram 
par(mar=data_NA(0, 3.1, 1.1, 2.1))
boxplot(my_variable, horizontal=TRUE, ylim=data_NA(-10,20), xaxt="n", col=rgb(0.8,0.8,0,0.5), frame=F)
par(mar=data_NA(4, 3.1, 1.1, 2.1))
hist(my_variable, breaks=40, col=rgb(0.2,0.8,0.5,0.5), border=F, main="", xlab="incidents_85_99", xlim=data_NA(-10,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NIKA~1.PIN\AppData\Local\Temp/ipykernel_10784/38567911.py in <module>
#       1 # Create data
# ----> 2 my_variable=data_NA(np.random.normal(1000, 0, 2) , np.random.normal(1000, 9, 2))
#       3
#       4 # Layout to split the screen
#       5 layout(mat = matrix(data_NA(1,2),2,1, byrow=TRUE),  height = data_NA(1,8))
#
# TypeError: 'DataFrame' object is not callable

# %%
# Libraries
#library(ggplot2)

# Create data
data <- data.frame(x=seq(1,30), y=abs(np.random.normal(30)))
 
# Plot
ggplot(data, aes(x=x, y=y)) + geom_point() + geom_segment( aes(x=x, xend=x, y=0, yend=y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\NIKA~1.PIN\AppData\Local\Temp/ipykernel_10784/616863643.py in <module>
#       3
#       4 # Create data
# ----> 5 data <- data.frame(x=seq(1,30), y=abs(np.random.normal(30)))
#       6
#       7 # Plot
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'frame'
